# %% [markdown]
# # Animation Demonstration

# %%
from matplotlib import pyplot as plt
import matplotlib.lines as mlines
# %matplotlib inline

import numpy as np

def rotate(x, y, cx, cy, theta):
    r_matrix = np.array([[np.cos(np.radians(angle)), -np.sin(np.radians(angle))],
                        [np.sin(np.radians(angle)), np.cos(np.radians(angle))]])

def circle(theta, cx, cy, r):
    x = r * np.cos(theta) + cx
    y = r * np.sin(theta) + cy
    return x, y
    
thetas = np.arange(0, 2*np.pi, 0.01)
x, y = circle(thetas, 0, 0, 50)

plt.plot(x,y)
plt.plot([0, 10, 10, 0, 0], [0, 0, 10, 10, 0], lw=1.5, color='r')
plt.show()
